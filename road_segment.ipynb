# %%
import pandas as pd

# %%
region = pd.read_csv('data/Chicago_Traffic_Tracker_-_Congestion_Estimates_by_Regions.csv')
region
# Out:
#                                REGION   REGION_ID       WEST       EAST  \
# 0            Rogers Park - West Ridge           1 -87.709645 -87.654561
# 1                      Far North West           2 -87.846210 -87.747456
# 2        North Park-Albany-Linconl Sq           3 -87.747456 -87.674590
# 3                   Edge Water-Uptown           4 -87.674590 -87.646438
# 4       Dunning-Portage-Belmont Cragn           5 -87.846210 -87.747456
# 5      Irving Park-Avondale-North Ctr           6 -87.747456 -87.674590
# 6                Hermosa-Logan Square           7 -87.747456 -87.674590
# 7              Lincoln Park-Lake View           8 -87.674590 -87.619112
# 8                              Austin           9 -87.775947 -87.747456
# 9           Humboldt-Garfield Prk E/W          10 -87.747456 -87.691617
# 10                West Town-Near West          11 -87.691617 -87.647208
# 11                         Near North          12 -87.647208 -87.623080
# ...

# %%
segment = pd.read_csv('data/Chicago_Traffic_Tracker_-_Congestion_Estimates_by_Segments.csv')
segment
# Out:
#       SEGMENTID                                  STREET DIRECTION  \
# 0             1                                    55th        EB
# 1            10                                Garfield        EB
# 2           100                                 Ashland        NB
# 3          1000                                   Touhy        EB
# 4          1001                                   Touhy        EB
# 5          1002                                   Touhy        EB
# 6          1003                                   Touhy        EB
# 7          1004                                   Touhy        EB
# 8          1005                                   Touhy        EB
# 9          1006                                   Touhy        WB
# 10         1007                                   Touhy        WB
# 11         1008                                   Touhy        WB
# 12         1009                                   Touhy        WB
# ...

# %%
segment.STREET.value_counts()['55th']
# Out:
# 20

# %%
segment[segment.STREET=='55th'].sort_values('START_LONGITUDE', ascending=True)
# Out:
#      SEGMENTID STREET DIRECTION   FROM_STREET     TO_STREET  LENGTH  \
# 463        247   55th        EB  Narragansett        Austin    0.50
# 464        248   55th        EB        Austin       Central    0.50
# 345         14   55th        WB        Austin        Mobile    0.50
# 356         15   55th        WB       Central        Austin    0.50
# 465        249   55th        EB       Central       Laramie    0.50
# 467        250   55th        EB       Laramie        Cicero    0.54
# 367         16   55th        WB       Laramie       Central    0.50
# 468        251   55th        EB        Cicero       Kostner    0.46
# 378         17   55th        WB        Cicero       Laramie    0.54
# 469        252   55th        EB       Kostner       Pulaski    0.50
# 377        169   55th        WB       Kostner        Cicero    0.46
# 0            1   55th        EB       Pulaski  Central Park    0.50
# 379        170   55th        WB       Pulaski       Kostner    0.50
# ...
